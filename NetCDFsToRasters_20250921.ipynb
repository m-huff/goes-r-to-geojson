# %%
import os
import glob
import numpy as np
import rasterio
from rasterio.transform import from_origin
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from collections import Counter

# === CONFIG ===
DATA_DIR = r"E:\GOES-R Lightning Data\JULY-EAST"
OUTPUT_DIR = r"E:\GOES-R Lightning Data\JULY-EAST-RASTERS"
PIXEL_SCALE = 1e5  # scale factor so small values survive GeoTIFF save
THRESHOLD = 1.2e-05

# === Metric accumulators ===
sum_raster = None
count_raster = None
max_raster = None
weighted_raster = None
mean_sum = None
mean_count = None

# === orbital_slot counter ===
slot_counter = Counter()

# === Load files ===
files = glob.glob(os.path.join(DATA_DIR, "*.nc"))

for i, f in enumerate(files, start=1):
    with Dataset(f, "r") as ds:
        # --- read orbital_slot global attribute ---
        if "orbital_slot" in ds.ncattrs():
            slot = ds.getncattr("orbital_slot")
            slot_counter[slot] += 1
        else:
            slot_counter["UNKNOWN"] += 1

        # adjust variable name if needed (GLM L2 NetCDF files)
        energy = ds.variables["Total_Optical_energy"][:].filled(0)

        # skip if all zeros
        if np.all(energy == 0):
            continue

        # initialize arrays on first pass
        if sum_raster is None:
            shape = energy.shape
            sum_raster = np.zeros(shape, dtype=np.float64)
            count_raster = np.zeros(shape, dtype=np.float64)
            max_raster = np.zeros(shape, dtype=np.float64)
            weighted_raster = np.zeros(shape, dtype=np.float64)
            mean_sum = np.zeros(shape, dtype=np.float64)
            mean_count = np.zeros(shape, dtype=np.float64)

        # --- metric 1: sum ---
        sum_raster += energy

        # --- metric 2: count flashes > threshold ---
        count_raster += (energy > THRESHOLD).astype(np.float64)

        # --- metric 3: max flash energy ---
        max_raster = np.maximum(max_raster, energy)

        # --- metric 4: weighted intensity ---
        weighted_raster += energy * (energy > THRESHOLD)

        # --- metric 5: mean optical energy above threshold ---
        mask = energy > THRESHOLD
        mean_sum += np.where(mask, energy, 0)
        mean_count += mask.astype(np.float64)

    # --- print progress every 1000 files ---
    if i % 1000 == 0:
        print(f"Processed {i} files. Orbital slot counts so far:")
        for slot, count in slot_counter.items():
            print(f"  {slot}: {count}")

# avoid division by zero
mean_raster = np.divide(mean_sum, mean_count, out=np.zeros_like(mean_sum), where=mean_count > 0)

# === Scale results ===
sum_raster *= PIXEL_SCALE
count_raster *= PIXEL_SCALE
max_raster *= PIXEL_SCALE
weighted_raster *= PIXEL_SCALE
mean_raster *= PIXEL_SCALE

# === Save rasters ===
os.makedirs(OUTPUT_DIR, exist_ok=True)

def save_raster(arr, name):
    out_path = os.path.join(OUTPUT_DIR, f"{name}.tif")
    height, width = arr.shape
    transform = from_origin(0, 0, 1, 1)  # dummy transform
    with rasterio.open(
        out_path,
        "w",
        driver="GTiff",
        height=height,
        width=width,
        count=1,
        dtype="float32",
        crs=None,
        transform=transform,
    ) as dst:
        dst.write(arr.astype(np.float32), 1)

save_raster(sum_raster, "sum_energy")
save_raster(count_raster, "count_flashes")
save_raster(max_raster, "max_energy")
save_raster(weighted_raster, "weighted_intensity")
save_raster(mean_raster, "mean_energy")

# === Plot ===
fig, axes = plt.subplots(1, 5, figsize=(20, 5))
titles = ["Sum", "Count", "Max", "Weighted", "Mean"]
arrays = [sum_raster, count_raster, max_raster, weighted_raster, mean_raster]

for ax, arr, title in zip(axes, arrays, titles):
    im = ax.imshow(arr, cmap="inferno")
    ax.set_title(title)
    plt.colorbar(im, ax=ax, shrink=0.6)

plt.tight_layout()
plt.show()

# === Final orbital_slot summary ===
print("\nFinal orbital_slot counts:")
for slot, count in slot_counter.items():
    print(f"  {slot}: {count}")
# Out:
# Processed 1000 files. Orbital slot counts so far:
#   GOES-West: 1000
# Processed 2000 files. Orbital slot counts so far:
#   GOES-West: 2000
# Processed 3000 files. Orbital slot counts so far:
#   GOES-West: 3000
# Processed 4000 files. Orbital slot counts so far:
#   GOES-West: 4000
# Processed 5000 files. Orbital slot counts so far:
#   GOES-West: 5000
# Processed 6000 files. Orbital slot counts so far:
#   GOES-West: 6000
# Processed 7000 files. Orbital slot counts so far:
#   GOES-West: 7000
# Processed 8000 files. Orbital slot counts so far:
#   GOES-West: 8000
# Processed 9000 files. Orbital slot counts so far:
#   GOES-West: 9000
# Processed 10000 files. Orbital slot counts so far:
#   GOES-West: 10000
# Processed 11000 files. Orbital slot counts so far:
#   GOES-West: 11000
# Processed 12000 files. Orbital slot counts so far:
#   GOES-West: 12000
# Processed 13000 files. Orbital slot counts so far:
#   GOES-West: 13000
# Processed 14000 files. Orbital slot counts so far:
#   GOES-West: 14000
# Processed 15000 files. Orbital slot counts so far:
#   GOES-West: 15000
# Processed 16000 files. Orbital slot counts so far:
#   GOES-West: 16000
# Processed 17000 files. Orbital slot counts so far:
#   GOES-West: 17000
# Processed 18000 files. Orbital slot counts so far:
#   GOES-West: 18000
# Processed 19000 files. Orbital slot counts so far:
#   GOES-West: 19000
# Processed 20000 files. Orbital slot counts so far:
#   GOES-West: 20000
# Processed 21000 files. Orbital slot counts so far:
#   GOES-West: 21000
# Processed 22000 files. Orbital slot counts so far:
#   GOES-West: 22000
# Processed 23000 files. Orbital slot counts so far:
#   GOES-West: 23000
# Processed 24000 files. Orbital slot counts so far:
#   GOES-West: 24000
# Processed 25000 files. Orbital slot counts so far:
#   GOES-West: 25000
# Processed 26000 files. Orbital slot counts so far:
#   GOES-West: 26000
# Processed 27000 files. Orbital slot counts so far:
#   GOES-West: 27000
# Processed 28000 files. Orbital slot counts so far:
#   GOES-West: 28000
# Processed 29000 files. Orbital slot counts so far:
#   GOES-West: 29000
# Processed 30000 files. Orbital slot counts so far:
#   GOES-West: 30000
# Processed 31000 files. Orbital slot counts so far:
#   GOES-West: 31000
# Processed 32000 files. Orbital slot counts so far:
#   GOES-West: 32000
# Processed 33000 files. Orbital slot counts so far:
#   GOES-West: 33000
# Processed 34000 files. Orbital slot counts so far:
#   GOES-West: 34000
# Processed 35000 files. Orbital slot counts so far:
#   GOES-West: 35000
# Processed 36000 files. Orbital slot counts so far:
#   GOES-West: 36000
# Processed 37000 files. Orbital slot counts so far:
#   GOES-West: 37000
# Processed 38000 files. Orbital slot counts so far:
#   GOES-West: 38000
# Processed 39000 files. Orbital slot counts so far:
#   GOES-West: 39000
# Processed 40000 files. Orbital slot counts so far:
#   GOES-West: 40000
# Processed 41000 files. Orbital slot counts so far:
#   GOES-West: 41000
# Processed 42000 files. Orbital slot counts so far:
#   GOES-West: 42000
# Processed 43000 files. Orbital slot counts so far:
#   GOES-West: 43000
# Processed 44000 files. Orbital slot counts so far:
#   GOES-West: 44000
# Processed 45000 files. Orbital slot counts so far:
#   GOES-West: 45000
# Processed 46000 files. Orbital slot counts so far:
#   GOES-West: 46000
# Processed 47000 files. Orbital slot counts so far:
#   GOES-West: 47000
# Processed 48000 files. Orbital slot counts so far:
#   GOES-West: 48000
# Processed 49000 files. Orbital slot counts so far:
#   GOES-West: 49000
# Processed 50000 files. Orbital slot counts so far:
#   GOES-West: 50000
# Processed 51000 files. Orbital slot counts so far:
#   GOES-West: 51000
# Processed 52000 files. Orbital slot counts so far:
#   GOES-West: 52000
# Processed 53000 files. Orbital slot counts so far:
#   GOES-West: 53000
# Processed 54000 files. Orbital slot counts so far:
#   GOES-West: 54000
# Processed 55000 files. Orbital slot counts so far:
#   GOES-West: 55000
# Processed 56000 files. Orbital slot counts so far:
#   GOES-West: 56000
# Processed 57000 files. Orbital slot counts so far:
#   GOES-West: 57000
# Processed 58000 files. Orbital slot counts so far:
#   GOES-West: 58000
# Processed 59000 files. Orbital slot counts so far:
#   GOES-West: 59000
# Processed 60000 files. Orbital slot counts so far:
#   GOES-West: 60000
# Processed 61000 files. Orbital slot counts so far:
#   GOES-West: 61000
# Processed 62000 files. Orbital slot counts so far:
#   GOES-West: 62000
# Processed 63000 files. Orbital slot counts so far:
#   GOES-West: 63000
# Processed 64000 files. Orbital slot counts so far:
#   GOES-West: 64000
# Processed 65000 files. Orbital slot counts so far:
#   GOES-West: 65000
# Processed 66000 files. Orbital slot counts so far:
#   GOES-West: 66000
# Processed 67000 files. Orbital slot counts so far:
#   GOES-West: 67000
# Processed 68000 files. Orbital slot counts so far:
#   GOES-West: 68000
# Processed 69000 files. Orbital slot counts so far:
#   GOES-West: 69000
# Processed 70000 files. Orbital slot counts so far:
#   GOES-West: 70000
# Processed 71000 files. Orbital slot counts so far:
#   GOES-West: 71000
# Processed 72000 files. Orbital slot counts so far:
#   GOES-West: 72000
# Processed 73000 files. Orbital slot counts so far:
#   GOES-West: 73000
# Processed 74000 files. Orbital slot counts so far:
#   GOES-West: 74000
# Processed 75000 files. Orbital slot counts so far:
#   GOES-West: 75000
# Processed 76000 files. Orbital slot counts so far:
#   GOES-West: 76000
# Processed 77000 files. Orbital slot counts so far:
#   GOES-West: 77000
# Processed 78000 files. Orbital slot counts so far:
#   GOES-West: 78000
# Processed 79000 files. Orbital slot counts so far:
#   GOES-West: 79000
# Processed 80000 files. Orbital slot counts so far:
#   GOES-West: 80000
# Processed 81000 files. Orbital slot counts so far:
#   GOES-West: 81000
# Processed 82000 files. Orbital slot counts so far:
#   GOES-West: 82000
# Processed 83000 files. Orbital slot counts so far:
#   GOES-West: 83000
# Processed 84000 files. Orbital slot counts so far:
#   GOES-West: 84000
# Processed 85000 files. Orbital slot counts so far:
#   GOES-West: 85000
# Processed 86000 files. Orbital slot counts so far:
#   GOES-West: 86000
# Processed 87000 files. Orbital slot counts so far:
#   GOES-West: 87000
# Processed 88000 files. Orbital slot counts so far:
#   GOES-West: 88000
# Processed 89000 files. Orbital slot counts so far:
#   GOES-West: 89000
# Processed 90000 files. Orbital slot counts so far:
#   GOES-West: 90000
# Processed 91000 files. Orbital slot counts so far:
#   GOES-West: 91000
# Processed 92000 files. Orbital slot counts so far:
#   GOES-West: 92000
# Processed 93000 files. Orbital slot counts so far:
#   GOES-West: 93000
# Processed 94000 files. Orbital slot counts so far:
#   GOES-West: 94000
# Processed 95000 files. Orbital slot counts so far:
#   GOES-West: 95000
# Processed 96000 files. Orbital slot counts so far:
#   GOES-West: 96000
# Processed 97000 files. Orbital slot counts so far:
#   GOES-West: 97000
# Processed 98000 files. Orbital slot counts so far:
#   GOES-West: 98000
# Processed 99000 files. Orbital slot counts so far:
#   GOES-West: 99000
# Processed 100000 files. Orbital slot counts so far:
#   GOES-West: 100000
# Processed 101000 files. Orbital slot counts so far:
#   GOES-West: 101000
# Processed 102000 files. Orbital slot counts so far:
#   GOES-West: 102000
# Processed 103000 files. Orbital slot counts so far:
#   GOES-West: 103000
# Processed 104000 files. Orbital slot counts so far:
#   GOES-West: 104000
# Processed 105000 files. Orbital slot counts so far:
#   GOES-West: 105000
# Processed 106000 files. Orbital slot counts so far:
#   GOES-West: 106000
# Processed 107000 files. Orbital slot counts so far:
#   GOES-West: 107000
# Processed 108000 files. Orbital slot counts so far:
#   GOES-West: 108000
# Processed 109000 files. Orbital slot counts so far:
#   GOES-West: 109000
# Processed 110000 files. Orbital slot counts so far:
#   GOES-West: 110000
# Processed 111000 files. Orbital slot counts so far:
#   GOES-West: 111000
# Processed 112000 files. Orbital slot counts so far:
#   GOES-West: 112000
# Processed 113000 files. Orbital slot counts so far:
#   GOES-West: 113000
# Processed 114000 files. Orbital slot counts so far:
#   GOES-West: 114000
# Processed 115000 files. Orbital slot counts so far:
#   GOES-West: 115000
# Processed 116000 files. Orbital slot counts so far:
#   GOES-West: 116000
# Processed 117000 files. Orbital slot counts so far:
#   GOES-West: 117000
# Processed 118000 files. Orbital slot counts so far:
#   GOES-West: 118000
# Processed 119000 files. Orbital slot counts so far:
#   GOES-West: 119000
# Processed 120000 files. Orbital slot counts so far:
#   GOES-West: 120000
# Processed 121000 files. Orbital slot counts so far:
#   GOES-West: 121000
# Processed 122000 files. Orbital slot counts so far:
#   GOES-West: 122000
# Processed 123000 files. Orbital slot counts so far:
#   GOES-West: 123000
# Processed 124000 files. Orbital slot counts so far:
#   GOES-West: 124000
# Processed 125000 files. Orbital slot counts so far:
#   GOES-West: 125000
# Processed 126000 files. Orbital slot counts so far:
#   GOES-West: 126000
# Processed 127000 files. Orbital slot counts so far:
#   GOES-West: 127000
# Processed 128000 files. Orbital slot counts so far:
#   GOES-West: 128000
# Processed 129000 files. Orbital slot counts so far:
#   GOES-West: 129000
# Processed 130000 files. Orbital slot counts so far:
#   GOES-West: 130000
# Processed 131000 files. Orbital slot counts so far:
#   GOES-West: 131000
# Processed 132000 files. Orbital slot counts so far:
#   GOES-West: 132000
# Processed 133000 files. Orbital slot counts so far:
#   GOES-West: 133000
# C:\Users\micha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rasterio\__init__.py:378: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(
# Final orbital_slot counts:
#   GOES-West: 133467
